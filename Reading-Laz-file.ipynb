# %%
# !pip install open3d

# %%
# !pip install laspy

# %%
import copy, sys, os
import numpy as np

import matplotlib.pyplot as plt

import open3d as o3d
import laspy

# %%
# !pip install laspy[lazrs]

# %%
# !pip install laspy[laszip]

# %%
# !pip install laspy[lazrs,laszip]

# %%
pc1 = laspy.read('/content/Semis_2021_1224_6122_LA93_IGN78.laz')
xyz = np.vstack((pc1.x, pc1.y, pc1.z)).transpose()
xyz
# Out:
# array([[1.22499990e+06, 6.12151045e+06, 3.94480000e+02],
#        [1.22499998e+06, 6.12151071e+06, 3.94650000e+02],
#        [1.22499995e+06, 6.12151022e+06, 3.94240000e+02],
#        ...,
#        [1.22400001e+06, 6.12146915e+06, 4.37260000e+02],
#        [1.22400001e+06, 6.12145744e+06, 4.38590000e+02],
#        [1.22400001e+06, 6.12145527e+06, 4.37140000e+02]])

# %%
plt.plot(xyz[::1000,0], xyz[::1000,1], ',')
